# %% [markdown]
# ## M04_2_addressee_classification_SC
# A script that attempts the classification of the nominal 'addressee' variable for using a range of algorithms implemented using scikit learn and ~~the SMaPP text classifier~~ pipeline. Before this, I generated addressee classifications for all tweets using the tweet-text-filtering method (see script M03.R). So, beyond generating the classifications in this script, I will also compare them to the ones obtained through filtering.
#
# NL, 21/07/20
# NL, 23/07/20 -- updated for south carolina

# %%
import matplotlib.pyplot as plt
import random
import joblib

import sys
import logging
import json
import sklearn

import numpy as np
import pandas as pd

from pprint import pprint

# %% [markdown]
# #### Logging

# %%
logging.basicConfig(format='%(asctime)s - %(name)s - %(levelname)s - %(message)s', 
                    level=logging.INFO)
logger = logging.getLogger()
logger.setLevel(logging.DEBUG)
logging.getLogger("gensim").setLevel(logging.ERROR)
np.random.seed(989898)

# %% [markdown]
# ### FUNCTIONS

# %% [markdown]
# ### DATA IN

# %%
LABELLED_TWEETS = "/Users/nikloynes/Desktop/SENTIMENT/data/labelled_tweets/fmtd_with_metadata/"
UNLABELLED_TWEETS = "/Users/nikloynes/Desktop/SENTIMENT/data/located_users_tweets/with_mention_dummies/"
DATA_OUT = "/Users/nikloynes/Desktop/SENTIMENT/data/classifications/"

# %%
sc_df = pd.read_csv(LABELLED_TWEETS + 'south_carolina.csv',  dtype = {'id' : 'str'})

# %%
sc_unlabelled_df = pd.read_json(UNLABELLED_TWEETS + 'south_carolina.json', dtype = {'id' : 'str'}, lines=True)

# %%
sc_df
# Out:
#                      id                                               text  \
# 0    697640688997937152  RT @RejectedActor: BERNIE SANDERS WON THE NEW ...
# 1    700410917998108672  RT @AIwaysHorngry: Hillary Clinton's latest me...
# 2    699988484090683392  RT @DillonFox5: You got to watch this! \nOmega...
# 3    697234924693286912  RT @MonicaCrowley: There's a special place in ...
# 4    703307098126458880  RT @HFA: What happens when @HillaryClinton sho...
# 5    703396930462879744  RT @FoxNews: “The one person that Hillary and ...
# 6    701870892876484608  RT @ATLBlackStar: Danny Glover Recalls South C...
# 7    697561991850790912  RT @CauseWereGuys: RT for Puppy Monkey Baby\n\...
# 8    700045958315450368  RT @BernieSanders: Your volunteer shifts are w...
# 9    702950153582485504  @LauraOinAK  can't want #Hillary and 4 more ye...
# 10   696792073790328832  RT @DisickReactions: Rt for puppy monkey baby ...
# 11   701644903080656896  RT @SenSanders: It is disgraceful that million...
# 12   698958305461473280  RT @realDonaldTrump: How can @JebBush beat Hil...
# 13   702013045707440128  RT @WHCBLAD: Watch Hillary Clinton bark like a...
# 14   697254095741181952  Bernie Sanders announces shared wealth program...
# 15   701220404946460672  RT @politico: .@BernieSanders campaign says it...
# 16   697080625866653696  If Donald Trump and Bernie Sanders win the pri...
# 17   700515100390793216  RT @SmashedFinger: 🔥🔥🔥Bernin' down the house🔥🔥...
# 18   698704233156235264  RT @MattWalshBlog: Grades from hour 1: Cruz: A...
# 19   698881411772645376  RT @HillaryClinton: "It's outrageous that Repu...
# 20   697225987453390848                   RT @ShaqIsParamount: #Bernie2016
# 21   700321590362382336  RT @novenator: Bernie Sanders: ‘If We Can Rebu...
# 22   697884928164433920  RT @ShaunKing: CONTEXT.\n\nWhen Hillary Clinto...
# 23   699357235894468608  @drewmagary there is a Bernie Sanders version ...
# 24   701096177249476608  She is correct. @tedcruz is the only one to be...
# 25   703363361908588544  RT @BVGamble: And Hillary never said she was. ...
# 26   701226868318609408                          bernie sanders kan get VP
# 27   702857176994414592  RSVP for Presidential Town Hall Series with Se...
# 28   697273111587106816  RT @BGNatan: Bernie Sanders would be the Sixer...
# 29   696526755625111552  RT @RealTurntTravis: Who would be a better pre...
# ..                  ...                                                ...
# 970  699720528513384448  Saw Bernie for like 2.5 seconds today 😭 #FEELT...
# 971  700022154579079168  Thought?&gt;&gt;&gt;Eyeing South Carolina, Hil...
# 972  702304122494656512  Serving a 10 top of Bernie Sanders klan.... Tw...
# 973  702106392954433536  Hillary Clinton appearing at a town hall in No...
# 974  702982241648037888  RT @jonstefanski01: #SCPrimary #SCPrimary2016 ...
# 975  699651230637789184  @WillWhitsonWIS @wis10 @BernieSanders just lik...
# 976  697584350490185728  RT @laurenduca: An open letter to all @Hillary...
# 977  697956597054574592  RT @chanelpuke: RT for Ron Swanson Like for Hi...
# 978  699029750963044352  RT @JesseRyanUSA: If your boyfriend votes for ...
# 979  703023216646815744  RT @GovJimHodges: Introducing President Bill C...
# 980  697818195567050752  RT @TweetLikeAGirI: RT for Ron Swanson\nLike f...
# 981  699429702277189632  RT @mikandynothem: ✔RETWEET✔ if these FOUR rea...
# 982  696419993026633728                             @HillaryClinton great!
# 983  700530866792095744  RT @HillaryClinton: We cannot back down from b...
# 984  700865839994707968  RT @DaleF3: Jim Clyburn Endorses Hillary Clint...
# 985  702351222204792832                        @HillaryClinton disgusting!
# 986  702980669832560640  RT @Nvr4Get91101: If you don't know who @Hilla...
# 987  701218291050745856  RT @weknowwhatsbest: Today Bernie Sanders said...
# 988  702973749205856256  I never heard Trump call blacks super predator...
# 989  701475990887931904  RT @FaceTheNation: "Remember this: I'm the per...
# 990  698542629030653952  He's pretty much got my vote if Bloomberg does...
# 991  702127473081896960  @jillybee72 White people can come together and...
# 992  701589920037490688  #berniesanders #feelthebern #fujifilm #x100s @...
# 993  700372202831659008  RT @thyatt3: Voting for Bernie I suggest you r...
# 994  703314696003297280  Breaking: Dick van Dyke Endorses Bernie Sander...
# 995  703356618835099648  RT @AshleighWSAV: #BillClinton now answering t...
# 996  699087172780093440  RT @LisaVikingstad: Hillary Clinton meeting Bl...
# 997  703424455767363584  RT @skropf47: Former Labor Secretary Robert Re...
# 998  696491171502276608  RT @mnnoc: It's official: @mnnoc is hosting a ...
# 999  698014575942217728  Working under bernie sanders during my fall br...
#
#      bernie_score  hillary_score        addressee            timestamp  \
# 0             4.0            NaN   Bernie Sanders  2016-02-10 23:37:56
# 1             NaN           -1.0  Hillary Clinton  2016-02-18 15:05:50
# 2             3.0            NaN   Bernie Sanders  2016-02-17 11:07:14
# 3            -4.0            NaN   Bernie Sanders  2016-02-09 20:45:34
# 4             NaN            3.0  Hillary Clinton  2016-02-26 14:54:13
# 5             NaN           -2.0  Hillary Clinton  2016-02-26 20:51:11
# 6             3.0            NaN   Bernie Sanders  2016-02-22 15:47:15
# 7             NaN           -2.0  Hillary Clinton  2016-02-10 18:25:13
# 8             3.0            NaN   Bernie Sanders  2016-02-17 14:55:37
# 9             NaN           -3.0  Hillary Clinton  2016-02-25 15:15:51
# 10           -2.0            NaN   Bernie Sanders  2016-02-08 15:25:50
# 11            3.0            NaN   Bernie Sanders  2016-02-22 00:49:15
# 12            NaN           -1.0  Hillary Clinton  2016-02-14 14:53:40
# 13            NaN           -3.0  Hillary Clinton  2016-02-23 01:12:07
# 14           -1.0            NaN   Bernie Sanders  2016-02-09 22:01:45
# 15            2.0            NaN   Bernie Sanders  2016-02-20 20:42:27
# 16           -3.0            NaN   Bernie Sanders  2016-02-09 10:32:26
# 17            4.0            NaN   Bernie Sanders  2016-02-18 21:59:49
# 18            NaN            NaN          neither  2016-02-13 22:04:05
# 19            NaN            3.0  Hillary Clinton  2016-02-14 09:48:07
# 20            NaN            NaN          neither  2016-02-09 20:10:03
# 21            3.0            NaN   Bernie Sanders  2016-02-18 09:10:53
# 22            3.0           -3.0             both  2016-02-11 15:48:27
# 23           -4.0            NaN   Bernie Sanders  2016-02-15 17:18:53
# 24            NaN           -2.0  Hillary Clinton  2016-02-20 12:28:49
# 25            NaN            2.0  Hillary Clinton  2016-02-26 18:37:47
# 26            1.0            NaN   Bernie Sanders  2016-02-20 21:08:08
# 27            NaN            2.0  Hillary Clinton  2016-02-25 09:06:24
# 28            3.0            NaN   Bernie Sanders  2016-02-09 23:17:19
# 29            NaN           -2.0  Hillary Clinton  2016-02-07 21:51:34
# ..            ...            ...              ...                  ...
# 970           3.0            NaN   Bernie Sanders  2016-02-16 17:22:28
# 971           0.0            0.0             both  2016-02-17 13:21:02
# 972          -3.0            NaN   Bernie Sanders  2016-02-23 20:28:45
# 973           NaN            1.0  Hillary Clinton  2016-02-23 07:23:03
# 974           3.0           -3.0             both  2016-02-25 17:23:21
# 975          -3.0            NaN   Bernie Sanders  2016-02-16 12:47:06
# 976           0.0            3.0             both  2016-02-10 19:54:04
# 977           NaN           -2.0  Hillary Clinton  2016-02-11 20:33:14
# 978          -3.0            NaN   Bernie Sanders  2016-02-14 19:37:34
# 979           NaN            3.0  Hillary Clinton  2016-02-25 20:06:11
# 980           NaN           -2.0  Hillary Clinton  2016-02-11 11:23:17
# 981           NaN           -3.0  Hillary Clinton  2016-02-15 22:06:50
# 982           NaN            3.0  Hillary Clinton  2016-02-07 14:47:19
# 983           NaN            3.0  Hillary Clinton  2016-02-18 23:02:28
# 984           3.0            3.0             both  2016-02-19 21:13:32
# 985           NaN           -4.0  Hillary Clinton  2016-02-23 23:35:55
# 986           NaN           -3.0  Hillary Clinton  2016-02-25 17:17:07
# 987           3.0           -3.0             both  2016-02-20 20:34:03
# 988           NaN           -3.0  Hillary Clinton  2016-02-25 16:49:37
# 989           NaN           -1.0  Hillary Clinton  2016-02-21 13:38:03
# 990           1.0            NaN   Bernie Sanders  2016-02-13 11:21:55
# 991           0.0            NaN   Bernie Sanders  2016-02-23 08:46:49
# 992           3.0            NaN   Bernie Sanders  2016-02-21 21:10:46
# 993           3.0            NaN   Bernie Sanders  2016-02-18 12:32:00
# 994           3.0            NaN   Bernie Sanders  2016-02-26 15:24:25
# 995           NaN           -3.0  Hillary Clinton  2016-02-26 18:11:00
# 996           NaN           -3.0  Hillary Clinton  2016-02-14 23:25:45
# 997           2.0            NaN   Bernie Sanders  2016-02-26 22:40:33
# 998           0.0            NaN   Bernie Sanders  2016-02-07 19:30:10
# 999           3.0            NaN   Bernie Sanders  2016-02-12 00:23:38
#
#         user_id    municipality           admin         county  ideology_bin  \
# 0    1864426772         Clemson  South Carolina  United States           NaN
# 1     536538522             NaN  South Carolina  United States  conservative
# 2     168838079        Columbia  South Carolina  United States           NaN
# 3     547969582      Greenville  South Carolina  United States  conservative
# 4     105774201        Columbia  South Carolina  United States       liberal
# 5      72263304        Bluffton  South Carolina  United States  conservative
# 6     338048005        Columbia  South Carolina  United States           NaN
# 7      45897633         Clemson  South Carolina  United States           NaN
# 8    3188746707      Charleston  South Carolina  United States       liberal
# 9      98903097    Mt. Pleasant  South Carolina  United States  conservative
# 10   3237439030     Spartanburg  South Carolina  United States           NaN
# 11    173490967      Charleston  South Carolina  United States       liberal
# 12    239244397        Columbia  South Carolina  United States  conservative
# 13   2202013580        Columbia  South Carolina  United States           NaN
# 14    246533164         Clemson  South Carolina  United States  conservative
# 15    159474455      Charleston  South Carolina  United States      moderate
# 16     72128563      Charleston  South Carolina  United States           NaN
# 17     74947747  Travelers Rest  South Carolina  United States       liberal
# 18    323313766      Greenville  South Carolina  United States  conservative
# 19     16571124          Seneca  South Carolina  United States       liberal
# 20   2157190640     Summerville  South Carolina  United States           NaN
# 21     40688994        Columbia  South Carolina  United States           NaN
# 22    382428682        Columbia  South Carolina  United States           NaN
# 23     14132295             NaN  South Carolina  United States  conservative
# 24     86308657    Mt. Pleasant  South Carolina  United States  conservative
# 25    204653280      Greenville  South Carolina  United States       liberal
# 26   2326058522        Columbia  South Carolina  United States           NaN
# 27   1128353214      Charleston  South Carolina  United States       liberal
# 28    374021244         Clemson  South Carolina  United States      moderate
# 29   3355434923          Easley  South Carolina  United States           NaN
# ..          ...             ...             ...            ...           ...
# 970  1480788104      Charleston  South Carolina  United States           NaN
# 971   225472716      Charleston  South Carolina  United States           NaN
# 972    69199872        Columbia  South Carolina  United States  conservative
# 973   244377884      Charleston  South Carolina  United States      moderate
# 974    15874997        Columbia  South Carolina  United States       liberal
# 975   284550199       Rock Hill  South Carolina  United States           NaN
# 976   625562575        Columbia  South Carolina  United States       liberal
# 977   330789194         Clemson  South Carolina  United States           NaN
# 978   393698274         Hanahan  South Carolina  United States  conservative
# 979  3434369195        Columbia  South Carolina  United States  conservative
# 980  1653309547          Sumter  South Carolina  United States           NaN
# 981    15711610        Columbia  South Carolina  United States  conservative
# 982   490693669      Charleston  South Carolina  United States       liberal
# 983    34635167        Columbia  South Carolina  United States       liberal
# 984   870663710        Columbia  South Carolina  United States      moderate
# 985   392883246        Columbia  South Carolina  United States      moderate
# 986   362540519        Columbia  South Carolina  United States  conservative
# 987   341879551         Liberty  South Carolina  United States  conservative
# 988    95365988          Sumter  South Carolina  United States      moderate
# 989     6796602      Greenville  South Carolina  United States       liberal
# 990    23658556      Charleston  South Carolina  United States           NaN
# 991   509080755      Greenville  South Carolina  United States           NaN
# 992    73707319        Columbia  South Carolina  United States       liberal
# 993   396590636    Myrtle Beach  South Carolina  United States           NaN
# 994    28730141        Woodford  South Carolina  United States      moderate
# 995  1636702268        Columbia  South Carolina  United States  conservative
# 996    31606315        Columbia  South Carolina  United States       liberal
# 997    14693499      Charleston  South Carolina  United States      moderate
# 998  3039462916        Columbia  South Carolina  United States       liberal
# 999   126746157        Columbia  South Carolina  United States           NaN
#
#      n_tweets  n_hillary  n_bernie  pop_norm  pop_quantiles
# 0           1          0         1  0.514039            4.0
# 1           3          2         1       NaN            NaN
# 2           1          0         1  8.093695            4.0
# 3           1          0         1  3.437969            4.0
# 4           6          3         3  8.093695            4.0
# 5           1          1         0  0.423701            4.0
# 6           1          0         1  8.093695            4.0
# 7           1          1         0  0.514039            4.0
# 8           2          1         1  7.489974            4.0
# 9           5          5         0       NaN            NaN
# 10          1          1         0  2.032244            4.0
# 11          2          0         2  7.489974            4.0
# 12          2          2         0  8.093695            4.0
# 13          1          1         0  8.093695            4.0
# 14          1          0         1  0.514039            4.0
# 15          2          0         2  7.489974            4.0
# 16          1          0         1  7.489974            4.0
# 17          1          0         1 -0.098880            4.0
# 18          1          0         1  3.437969            4.0
# 19          3          1         2  0.132780            4.0
# 20          2          0         2  2.451346            4.0
# 21          3          0         3  8.093695            4.0
# 22          1          1         1  8.093695            4.0
# 23          1          0         1       NaN            NaN
# 24          2          2         0       NaN            NaN
# 25         89         45        65  3.437969            4.0
# 26          1          0         1  8.093695            4.0
# 27          1          1         0  7.489974            4.0
# 28          1          0         1  0.514039            4.0
# 29          1          1         0  0.914023            4.0
# ..        ...        ...       ...       ...            ...
# 970         2          0         2  7.489974            4.0
# 971         2          2         2  7.489974            4.0
# 972         2          0         2  8.093695            4.0
# 973        13          2        12  7.489974            4.0
# 974        13          3        13  8.093695            4.0
# 975         2          0         2  3.946819            4.0
# 976         1          1         1  8.093695            4.0
# 977         1          1         0  0.514039            4.0
# 978         1          0         1  0.782885            4.0
# 979         1          1         0  8.093695            4.0
# 980         1          1         0  2.262918            4.0
# 981         1          1         0  8.093695            4.0
# 982         1          1         0  7.489974            4.0
# 983         1          1         0  8.093695            4.0
# 984         1          1         1  8.093695            4.0
# 985         3          3         0  8.093695            4.0
# 986         8          8         1  8.093695            4.0
# 987         1          1         1 -0.184750            3.0
# 988         3          3         0  2.262918            4.0
# 989         1          1         0  3.437969            4.0
# 990         1          0         1  7.489974            4.0
# 991         4          0         4  3.437969            4.0
# 992         1          0         1  8.093695            4.0
# 993         2          0         2  1.381547            4.0
# 994         6          3         4 -0.387370            1.0
# 995         6          5         3  8.093695            4.0
# 996         1          1         0  8.093695            4.0
# 997       117         36        95  7.489974            4.0
# 998         1          0         1  8.093695            4.0
# 999         1          0         1  8.093695            4.0
#
# [1000 rows x 16 columns]

# %%
from io import StringIO
col = ['id', 'addressee', 'text']
sc_df = sc_df[col]
sc_df = sc_df[pd.notnull(sc_df['text'])]
sc_df.columns = ['id', 'addressee', 'text']
sc_df['category_id'] = sc_df['addressee'].factorize()[0]
category_id_sc_df = sc_df[['addressee', 'category_id']].drop_duplicates().sort_values('category_id')
category_to_id = dict(category_id_sc_df.values)
id_to_category = dict(category_id_sc_df[['category_id', 'addressee']].values)
sc_df.head()
# Out:
#                    id        addressee  \
# 0  697640688997937152   Bernie Sanders
# 1  700410917998108672  Hillary Clinton
# 2  699988484090683392   Bernie Sanders
# 3  697234924693286912   Bernie Sanders
# 4  703307098126458880  Hillary Clinton
#
#                                                 text  category_id
# 0  RT @RejectedActor: BERNIE SANDERS WON THE NEW ...            0
# 1  RT @AIwaysHorngry: Hillary Clinton's latest me...            1
# 2  RT @DillonFox5: You got to watch this! \nOmega...            0
# 3  RT @MonicaCrowley: There's a special place in ...            0
# 4  RT @HFA: What happens when @HillaryClinton sho...            1

# %%
sc_df.category_id.unique()
# Out:
# array([0, 1, 2, 3])

# %%
fig = plt.figure(figsize=(8,6))
sc_df.groupby('addressee').text.count().plot.bar(ylim=0)
plt.show()

# classes are unbalanced!!!
# BUT -- COMPARED TO NEW HAMPSHIRE, SANDERS AND CLINTON ARE WAY CLOSER TOGETHER!!!
# Out:
# 2020-07-23 14:11:32,017 - matplotlib.axes._base - DEBUG - update_title_pos
# 2020-07-23 14:11:32,056 - matplotlib.axes._base - DEBUG - update_title_pos
# 2020-07-23 14:11:32,079 - matplotlib.axes._base - DEBUG - update_title_pos
# 2020-07-23 14:11:32,099 - matplotlib.axes._base - DEBUG - update_title_pos

# %% [markdown]
# #### Upsampling all response categories
#
# As shown in the bar plot above, the 4 classes (Bernie, Hillary, both, neither) are unbalanced in the training data. While there is no guarantee that this is the best thing to do in such a case, it makes sense to create an upsampled dataset in which all response categories are equally prevalent.

# %%
sc_df.category_id.value_counts()
# Out:
# 0    471
# 1    392
# 3     92
# 2     45
# Name: category_id, dtype: int64

# %%
train_zero = sc_df[sc_df.category_id==0]
train_one = sc_df[sc_df.category_id==1]
train_two = sc_df[sc_df.category_id==2]
train_three = sc_df[sc_df.category_id==3]

train_one_upsampled = sklearn.utils.resample(train_one,
                               replace=True, 
                               n_samples=len(train_zero),
                               random_state=123)

train_two_upsampled = sklearn.utils.resample(train_two,
                               replace=True, 
                               n_samples=len(train_zero),
                               random_state=123)

train_three_upsampled = sklearn.utils.resample(train_three,
                                 replace=True, 
                                 n_samples=len(train_zero),
                                 random_state=123)

sc_upsampled_df = pd.concat([train_zero, train_one_upsampled, train_two_upsampled, train_three_upsampled])
sc_upsampled_df['category_id'].value_counts()
# Out:
# 3    471
# 2    471
# 1    471
# 0    471
# Name: category_id, dtype: int64

# %% [markdown]
# #### Vectorising the data to tf-idf
#
# Sklearn can't learn the relationship between texts and labels directly -- first, the text needs to be transformed to a numerical representation. The below cell does this using the tf-ids method (term frequency, inverse document frequency). This method is likely superior to the simple 'bag of words' (term frequency) model, as it not only takes into account the frequency of a given term within a document (tweet), but also how it is relatively differenlty likely to appear in a given document. This helps the classifier decide on the correct class for a given tweet.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf = TfidfVectorizer(sublinear_tf=True, 
                        min_df=5, 
                        norm='l2', 
                        encoding='latin-1', 
                        ngram_range=(1, 2), 
                        stop_words='english')

features = tfidf.fit_transform(sc_upsampled_df.text)
labels = sc_upsampled_df.category_id
features.shape
# Out:
# (1884, 1898)

# %% [markdown]
# #### Exploratory metrics: Most correlated n-grams / training labels

# %%
from sklearn.feature_selection import chi2
N = 2

for addressee, category_id in sorted(category_to_id.items()):
    features_chi2 = chi2(features, labels == category_id)
    indices = np.argsort(features_chi2[0])
    feature_names = np.array(tfidf.get_feature_names())[indices]
    unigrams = [v for v in feature_names if len(v.split(' ')) == 1]
    bigrams = [v for v in feature_names if len(v.split(' ')) == 2]
    print("# '{}':".format(addressee))
    print("  . Most correlated unigrams:\n. {}".format('\n. '.join(unigrams[-N:])))
    print("  . Most correlated bigrams:\n. {}".format('\n. '.join(bigrams[-N:])))
# Out:
# # 'Bernie Sanders':
#   . Most correlated unigrams:
# . sanders
# . bernie
#   . Most correlated bigrams:
# . sanders https
# . bernie sanders
# # 'Hillary Clinton':
#   . Most correlated unigrams:
# . clinton
# . hillary
#   . Most correlated bigrams:
# . hillary clinton
# . clinton https
# # 'both':
#   . Most correlated unigrams:
# . jebbush
# . demdebate
#   . Most correlated bigrams:
# . sanders hillary
# . berniesanders hillaryclinton
# # 'neither':
#   . Most correlated unigrams:
# . shaqisparamount
# . balls
#   . Most correlated bigrams:
# . shaqisparamount bernie2016
# . rt shaqisparamount

# %% [markdown]
# #### Instantiating the data for training
#
# In this step, the training data gets transformed into the right format and split, so that multiple algorithms can be applied to learning the connection between features and labels. For this purpose, I test:
#
# - Naive Bayes
# - SVM
# - Random Forest
# - Logistic Regression

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.naive_bayes import MultinomialNB

X_train, X_test, y_train, y_test = train_test_split(sc_upsampled_df['text'], sc_upsampled_df['addressee'], random_state = 0)

count_vect = CountVectorizer()
X_train_counts = count_vect.fit_transform(X_train)

tfidf_transformer = TfidfTransformer()
X_train_tfidf = tfidf_transformer.fit_transform(X_train_counts)
clf = MultinomialNB().fit(X_train_tfidf, y_train)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import LinearSVC
from sklearn.model_selection import cross_val_score

models = [
    RandomForestClassifier(n_estimators=200, max_depth=3, random_state=0),
    LinearSVC(),
    MultinomialNB(),
    LogisticRegression(random_state=0),
]

CV = 20

cv_df = pd.DataFrame(index=range(CV * len(models)))

entries = []
for model in models:
    model_name = model.__class__.__name__
    accuracies = cross_val_score(model, features, labels, scoring='accuracy', cv=CV)
    for fold_idx, accuracy in enumerate(accuracies):
        entries.append((model_name, fold_idx, accuracy))
        cv_df = pd.DataFrame(entries, columns=['model_name', 'fold_idx', 'accuracy'])
        
import seaborn as sns
sns.boxplot(x='model_name', y='accuracy', data=cv_df)
sns.stripplot(x='model_name', y='accuracy', data=cv_df, 
              size=8, jitter=True, edgecolor="gray", linewidth=2)
plt.show()
# Out:
# /anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# 2020-07-23 14:15:39,163 - matplotlib.axes._base - DEBUG - update_title_pos
# 2020-07-23 14:15:39,198 - matplotlib.axes._base - DEBUG - update_title_pos
# 2020-07-23 14:15:39,229 - matplotlib.axes._base - DEBUG - update_title_pos
# 2020-07-23 14:15:39,251 - matplotlib.axes._base - DEBUG - update_title_pos

# %%
cv_df.groupby('model_name').accuracy.mean()
# Out:
# model_name
# LinearSVC                 0.981952
# LogisticRegression        0.973437
# MultinomialNB             0.942686
# RandomForestClassifier    0.803397
# Name: accuracy, dtype: float64

# %% [markdown]
# #### It appears that SVM is the best model for this task. Now, to tune the hyper-parameters.

# %%
from sklearn.svm import SVC

# new model that incorporates probabilities. this might help decide which label to choose when 
# filtering-derived and ML-derived classifications are different.
model = SVC(kernel='linear', probability=True, random_state=0)
X_train, X_test, y_train, y_test, indices_train, indices_test = train_test_split(features, labels, sc_upsampled_df.index, test_size=0.33, random_state=0)

model.fit(X_train, y_train)

y_pred = model.predict(X_test)

from sklearn.metrics import confusion_matrix

conf_mat = confusion_matrix(y_test, y_pred)

fig, ax = plt.subplots(figsize=(10,10))
sns.heatmap(conf_mat, annot=True, fmt='d',
            xticklabels=category_id_sc_df.addressee.values, yticklabels=category_id_sc_df.addressee.values)
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.show()
# Out:
# 2020-07-23 14:19:06,505 - matplotlib.colorbar - DEBUG - locator: <matplotlib.ticker.MaxNLocator object at 0x1a2df1b208>
# 2020-07-23 14:19:06,506 - matplotlib.colorbar - DEBUG - Using auto colorbar locator on colorbar
# 2020-07-23 14:19:06,506 - matplotlib.colorbar - DEBUG - locator: <matplotlib.ticker.MaxNLocator object at 0x1a2df1b208>
# 2020-07-23 14:19:06,507 - matplotlib.colorbar - DEBUG - Setting pcolormesh
# 2020-07-23 14:19:06,513 - matplotlib.axes._base - DEBUG - update_title_pos
# 2020-07-23 14:19:06,540 - matplotlib.axes._base - DEBUG - update_title_pos
# 2020-07-23 14:19:06,559 - matplotlib.axes._base - DEBUG - update_title_pos
# 2020-07-23 14:19:06,587 - matplotlib.axes._base - DEBUG - update_title_pos
# 2020-07-23 14:19:06,627 - matplotlib.axes._base - DEBUG - update_title_pos
# 2020-07-23 14:19:06,634 - matplotlib.axes._base - DEBUG - update_title_pos
# 2020-07-23 14:19:06,649 - matplotlib.axes._base - DEBUG - update_title_pos
# 2020-07-23 14:19:06,661 - matplotlib.axes._base - DEBUG - update_title_pos
# 2020-07-23 14:19:06,673 - matplotlib.axes._base - DEBUG - update_title_pos
# 2020-07-23 14:19:06,699 - matplotlib.axes._base - DEBUG - update_title_pos

# %% [markdown]
# The 'get_params()' method on the classifier object tells us which hyper-parameters were selected for this model. This allows us to tune the parameters using k-fold cross-validation. This is implemented using the 'GridSearchCV' method, using different tuning parameters defined in 'param_grid'

# %%
model.get_params()
# Out:
# {'C': 1.0,
#  'cache_size': 200,
#  'class_weight': None,
#  'coef0': 0.0,
#  'decision_function_shape': 'ovr',
#  'degree': 3,
#  'gamma': 'auto_deprecated',
#  'kernel': 'linear',
#  'max_iter': -1,
#  'probability': True,
#  'random_state': 0,
#  'shrinking': True,
#  'tol': 0.001,
#  'verbose': False}

# %%
param_grid = {'C': [1, 10, 50, 100, 200, 500, 1000, 10000], 'max_iter' : [1000, 10000, 100000]}

# %%
from sklearn.model_selection import GridSearchCV
clf = GridSearchCV(cv=10,estimator=model, param_grid=param_grid)
clf.fit(features, labels)
# Out:
# /anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:244: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:244: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:244: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:244: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:244: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:244: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:244: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:244: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:244: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:244: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:244: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:244: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:244: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:244: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:244: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:244: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:244: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:244: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:244: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:244: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:244: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:244: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:244: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:244: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:244: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:244: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:244: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:244: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:244: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:244: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:244: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:244: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:244: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:244: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:244: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:244: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# GridSearchCV(cv=10, error_score='raise-deprecating',
#        estimator=SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='linear', max_iter=-1, probability=True, random_state=0,
#   shrinking=True, tol=0.001, verbose=False),
#        fit_params=None, iid='warn', n_jobs=None,
#        param_grid={'C': [1, 10, 50, 100, 200, 500, 1000, 10000], 'max_iter': [1000, 10000, 100000]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=None, verbose=0)

# %% [markdown]
# ### The most accurate/predictive model is chosen using the 'best_estimator' attribute on the cross-validation object.

# %%
final_model = clf.best_estimator_
final_model
# Out:
# SVC(C=100, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='linear', max_iter=1000, probability=True, random_state=0,
#   shrinking=True, tol=0.001, verbose=False)

# %%
final_model.fit(X_train, y_train)
final_model_preds = final_model.predict(X_test)

# %%
from sklearn import metrics
print(metrics.classification_report(y_test, final_model_preds, target_names=sc_df['addressee'].unique()))
# Out:
#                  precision    recall  f1-score   support
#
#  Bernie Sanders       1.00      0.95      0.97       159
# Hillary Clinton       0.99      0.99      0.99       168
#         neither       0.99      1.00      0.99       164
#            both       0.95      0.99      0.97       131
#
#       micro avg       0.98      0.98      0.98       622
#       macro avg       0.98      0.98      0.98       622
#    weighted avg       0.98      0.98      0.98       622

# %% [markdown]
# ## Now to apply the model on previously unseen data!
#
# The previously unseen data is the 'nh_unlabelled_df' data frame. It needs to be slightly transformed first, including removal of columns that aren't relevant for this task. Also, the 'addressee' variable is transformed from the 'bernie_mention' and 'hillary_mention' variables, as these are dummies themselves, and not a 4-level categorical variable like the one we are looking to predict. The 'bernie_mention' and 'hillary_mention' variables come from the tweet text filtering approach taken in M_03.R.

# %%
col = ['id_str', 'text', 'bernie_mention', 'hillary_mention']
sc_unlabelled_df = sc_unlabelled_df[col]

# %%
sc_unlabelled_df['addressee'] = 'neither'
sc_unlabelled_df.loc[(sc_unlabelled_df.bernie_mention==True) & (sc_unlabelled_df.hillary_mention==True), 'addressee'] = 'both'
sc_unlabelled_df.loc[(sc_unlabelled_df.bernie_mention==True) & (sc_unlabelled_df.hillary_mention==False), 'addressee'] = 'Bernie Sanders'
sc_unlabelled_df.loc[(sc_unlabelled_df.bernie_mention==False) & (sc_unlabelled_df.hillary_mention==True), 'addressee'] = 'Hillary Clinton'
sc_unlabelled_df = sc_unlabelled_df[pd.notnull(sc_unlabelled_df['text'])]
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
# what does the naive mention classification say about distribution of mentions by candidate?
# let' see how it compares to the classified values.
sc_unlabelled_df.addressee.value_counts()
# Out:
# Bernie Sanders     17200
# Hillary Clinton    10502
# both                5325
# Name: addressee, dtype: int64

# %%
features_unseen = tfidf.transform(sc_unlabelled_df.text)
features_unseen.shape
# Out:
# (33027, 1898)

# %%
# make prediction on new data
preds_unseen_data = final_model.predict(features_unseen)
probs_unseen_data = final_model.predict_proba(features_unseen)

# %%
class_probabilites_df = pd.DataFrame(data=probs_unseen_data)
class_probabilites_df.columns = ['class_0', 'class_1', 'class_2', 'class_3']
class_probabilites_df = class_probabilites_df.round(decimals=3)

# %%
sc_unlabelled_df['preds_addressee'] = preds_unseen_data 
sc_unlabelled_df = pd.concat([sc_unlabelled_df, class_probabilites_df], axis=1)

# %%
sc_unlabelled_df
# Out:
#                    id_str                                               text  \
# 0      697270129218973696  RT @ali: There is no-pro Bernie Sanders pundit...
# 1      697270420249165824  RT @BernieSanders: I want you to imagine eight...
# 2      697271850712354816  @HillaryClinton's ideology has created the ser...
# 3      697276044651450368  RT @FinishLine: Bernie Sanders #ballislife htt...
# 4      697276639974187008  RT @politico: Turnout in New Hampshire? @Berni...
# 5      697063050931793920  RT @slipcases: @Arianna8927 The rise of Bernie...
# 6      697262976714276864  RT @BernieSanders: When we stand together, we ...
# 7      697262979553849344  RT @BernieSanders: When we stand together, we ...
# 8      697263192242855936  RT @BernieSanders: When we stand together, we ...
# 9      697263698382090240  Check out @RNS coverage of @BernieSanders #NHP...
# 10     697263851054702592  @MSNBC @BernieSanders He didn't earn that ball...
# 11     697264150058172416  RT @seanspicer: .@HillaryClinton lost to @Bern...
# 12     697264982342275072  RT @seanspicer: .@HillaryClinton lost to @Bern...
# 13     697265175976665088  @rgruenhaus @CWAUnion @BernieSanders People ha...
# 14     697271207003967488  RT @Cosmopolitan: Donald Trump and Bernie Sand...
# 15     697272453052166144  @CharleneCac what do you think of Bernie Sande...
# 16     697273107459997696  RT @Libertea2012: How Bernie Sanders Won New H...
# 17     697273599699374080  RT @BernieSanders: When we stand together, we ...
# 18     697273943825195008  #SandersWarren2016 Let's do this! @BernieSande...
# 19     697274009507991552  RT @MarkRuffalo: Vote @BernieSanders to win co...
# 20     697274113199640576  New Hampshire is ours. 🔥❤️ South Carolina your...
# 21     697275325890371584        What if Bernie Sanders is the Antichrist? 😳
# 22     697275594074152960  RT @HSRepublicansTX: Bernie Sanders right now:...
# 23     697276174687404032  RT @FinishLine: Bernie Sanders #ballislife htt...
# 24     697276963082366976  Hey Bernie, in the Spirit of Socialism you sho...
# 25     697281680437047296  RT @VoteBernie4Pres: #Neoliberalism much? Why ...
# 26     697282010016919552  @wy4bernie South Carolinians can go here: http...
# 27     697283100934537216  RT @ctdulcimer: THANKS, NH, nothing but net fo...
# 28     696923851503104000  RT @CrowdrTV: 1 precinct reporting: Sanders is...
# 29     696924381671518208  RT @politico: Results from Dixville Notch's 9 ...
# ...                   ...                                                ...
# 32997  698878463839768576  RT @Astorix23: Keep your eye on the ball, whet...
# 32998  699062090917617664  RT @oralmoshpit: @swerveahoe when carter is ac...
# 32999  698939293604188160  RT @HillaryClinton: Obama is president until J...
# 33000  698985451332435968  RT @realDonaldTrump: How can @JebBush beat Hil...
# 33001  699084365901336576  RT @WhennBoys: RT for Ron Swanson\nLike for Hi...
# 33002  698933109220368384  The Tragedy of Hillary Clinton (And Her Genera...
# 33003  698862446241447936  This y we need 2get 2D polls &amp; vote we nee...
# 33004  698877005727719424  RT @X_SocialMedia_X: OFF-SCRIPT Bill Clinton A...
# 33005  698934726468435968  RT @pushforward2014: I'm telling you #HillaryC...
# 33006  698958413506748416  RT @JSavoly: How Bernie Sanders lost me ... an...
# 33007  698901866168610816  RT @HillaryClinton: Obama is president until J...
# 33008  698741194390577152  RT @nytimes: Hillary Clinton denounces Senator...
# 33009  698873053124632576  RT @PatriotsBeacon: https://t.co/RNEXbathi3 @r...
# 33010  699021248014241792  RT @HillaryClinton: Black families are denied ...
# 33011  699040269556195328  More Hillary Clinton Emails Released, Includin...
# 33012  698961982498717696  @HillaryClinton Found these in my closet. Woul...
# 33013  698836760323825664  @HillaryClinton is an all encompassing candida...
# 33014  698835168996560896  RT @HillaryClinton: "Only Clinton can win in N...
# 33015  698743229815111680  RT @HillaryClinton: "Barack Obama is President...
# 33016  698850226057117696  RT @realDonaldTrump: How can @JebBush beat Hil...
# 33017  699008184309170176  RT @HillaryClinton: Obama is president until J...
# 33018  698911805154918400  RT @HillaryClinton: Obama is president until J...
# 33019  699058121587593216  Poll: South Carolina still solidly for Donald ...
# 33020  699016869945208832  RT @shawsaluto: Exactly &gt;&gt; and Karl Rove...
# 33021  698747105813331968  RT @realDonaldTrump: How can @JebBush beat Hil...
# 33022  698776298693533696  Hillary Clinton in Denmark, SC on Friday night...
# 33023  698859855696830464  RT @JeanetteJing: #Hillary2016's State Departm...
# 33024  698990041369022464  RT @evan_breen: hillary Clinton seem like she ...
# 33025  698915204483174400  RT @Maggyw519: 95%!Hillary's donations100 or l...
# 33026  698918850302238720  RT @HillaryClinton: National political directo...
#
#        bernie_mention  hillary_mention        addressee  preds_addressee  \
# 0                True             True             both                0
# 1                True            False   Bernie Sanders                0
# 2                True             True             both                0
# 3                True            False   Bernie Sanders                0
# 4                True            False   Bernie Sanders                0
# 5                True             True             both                0
# 6                True            False   Bernie Sanders                0
# 7                True            False   Bernie Sanders                0
# 8                True            False   Bernie Sanders                0
# 9                True            False   Bernie Sanders                0
# 10               True            False   Bernie Sanders                0
# 11               True             True             both                0
# 12               True             True             both                0
# 13               True            False   Bernie Sanders                0
# 14               True            False   Bernie Sanders                0
# 15               True            False   Bernie Sanders                0
# 16               True            False   Bernie Sanders                0
# 17               True            False   Bernie Sanders                0
# 18               True            False   Bernie Sanders                0
# 19               True            False   Bernie Sanders                0
# 20               True            False   Bernie Sanders                0
# 21               True            False   Bernie Sanders                0
# 22               True            False   Bernie Sanders                0
# 23               True            False   Bernie Sanders                0
# 24               True             True             both                3
# 25               True             True             both                0
# 26               True            False   Bernie Sanders                0
# 27               True            False   Bernie Sanders                0
# 28               True             True             both                3
# 29               True             True             both                3
# ...               ...              ...              ...              ...
# 32997            True             True             both                0
# 32998           False             True  Hillary Clinton                1
# 32999           False             True  Hillary Clinton                2
# 33000           False             True  Hillary Clinton                1
# 33001           False             True  Hillary Clinton                1
# 33002           False             True  Hillary Clinton                1
# 33003           False             True  Hillary Clinton                1
# 33004            True             True             both                1
# 33005            True             True             both                1
# 33006            True             True             both                3
# 33007           False             True  Hillary Clinton                2
# 33008           False             True  Hillary Clinton                1
# 33009           False             True  Hillary Clinton                1
# 33010           False             True  Hillary Clinton                1
# 33011           False             True  Hillary Clinton                1
# 33012           False             True  Hillary Clinton                1
# 33013           False             True  Hillary Clinton                3
# 33014           False             True  Hillary Clinton                1
# 33015           False             True  Hillary Clinton                1
# 33016           False             True  Hillary Clinton                1
# 33017           False             True  Hillary Clinton                2
# 33018           False             True  Hillary Clinton                2
# 33019           False             True  Hillary Clinton                1
# 33020           False             True  Hillary Clinton                1
# 33021           False             True  Hillary Clinton                1
# 33022           False             True  Hillary Clinton                1
# 33023           False             True  Hillary Clinton                1
# 33024           False             True  Hillary Clinton                1
# 33025            True             True             both                1
# 33026           False             True  Hillary Clinton                1
#
#        class_0  class_1  class_2  class_3
# 0        0.709    0.002    0.004    0.286
# 1        0.996    0.002    0.000    0.002
# 2        0.591    0.099    0.043    0.267
# 3        1.000    0.000    0.000    0.000
# 4        0.980    0.003    0.005    0.012
# 5        0.950    0.003    0.006    0.041
# 6        0.999    0.000    0.000    0.000
# 7        0.999    0.000    0.000    0.000
# 8        0.999    0.000    0.000    0.000
# 9        0.997    0.000    0.000    0.003
# 10       0.706    0.018    0.030    0.246
# 11       0.597    0.104    0.024    0.275
# 12       0.597    0.104    0.024    0.275
# 13       0.987    0.004    0.004    0.005
# 14       1.000    0.000    0.000    0.000
# 15       0.923    0.016    0.033    0.028
# 16       0.999    0.000    0.000    0.000
# 17       0.999    0.000    0.000    0.000
# 18       0.997    0.000    0.000    0.002
# 19       1.000    0.000    0.000    0.000
# 20       0.998    0.000    0.001    0.001
# 21       1.000    0.000    0.000    0.000
# 22       0.991    0.000    0.000    0.009
# 23       1.000    0.000    0.000    0.000
# 24       0.004    0.001    0.001    0.995
# 25       0.664    0.244    0.002    0.090
# 26       0.941    0.027    0.024    0.008
# 27       0.821    0.003    0.015    0.160
# 28       0.127    0.054    0.009    0.810
# 29       0.121    0.047    0.004    0.828
# ...        ...      ...      ...      ...
# 32997    0.833    0.134    0.002    0.031
# 32998    0.000    1.000    0.000    0.000
# 32999    0.010    0.027    0.962    0.001
# 33000    0.000    0.982    0.002    0.016
# 33001    0.001    0.997    0.000    0.001
# 33002    0.000    1.000    0.000    0.000
# 33003    0.204    0.645    0.105    0.046
# 33004    0.044    0.938    0.002    0.015
# 33005    0.102    0.882    0.004    0.012
# 33006    0.029    0.295    0.004    0.672
# 33007    0.010    0.027    0.962    0.001
# 33008    0.005    0.920    0.003    0.072
# 33009    0.001    0.980    0.001    0.018
# 33010    0.032    0.966    0.001    0.001
# 33011    0.000    0.993    0.006    0.001
# 33012    0.256    0.636    0.090    0.018
# 33013    0.094    0.114    0.038    0.753
# 33014    0.021    0.977    0.000    0.001
# 33015    0.013    0.958    0.020    0.010
# 33016    0.000    0.982    0.002    0.016
# 33017    0.010    0.027    0.962    0.001
# 33018    0.010    0.027    0.962    0.001
# 33019    0.004    0.991    0.003    0.002
# 33020    0.126    0.572    0.082    0.220
# 33021    0.000    0.982    0.002    0.016
# 33022    0.000    0.999    0.001    0.000
# 33023    0.179    0.798    0.006    0.017
# 33024    0.000    0.978    0.002    0.020
# 33025    0.028    0.816    0.027    0.128
# 33026    0.007    0.992    0.000    0.001
#
# [33027 rows x 10 columns]

# %%
# writing out nh_unlabelled_df to a csv file
sc_unlabelled_df.to_csv(DATA_OUT+'sc_addressee_classified.csv', index=False)

# %%
sc_unlabelled_df.preds_addressee.value_counts()
# Out:
# 0    18220
# 1    10573
# 3     3884
# 2      350
# Name: preds_addressee, dtype: int64

# %%
sc_unlabelled_df.addressee.value_counts()
# Out:
# Bernie Sanders     17200
# Hillary Clinton    10502
# both                5325
# Name: addressee, dtype: int64

# %% [markdown]
# # BELOW ARE INITIAL ATTEMPTS WITH VARIOUS TUTORIALS, ALSO A SEMI-SUCCESSFUL SMAPP PIPELINE IMPLEMENTATION

# %%
tokenizer = nltk.TweetTokenizer()

# %%
dataset = DataSet(input_=nh_df, name='new_hampshire',
                  field_mapping={'label': 'addressee', 'text': 'text'})

# %%
algorithms = ['random_forest', 'elasticnet', 'svm', 'naive_bayes']
feature_sets = ['embeddings', 'char_ngrams', 'word_ngrams']

# %%
for algorithm in algorithms:
    for feature_set in feature_sets:
        print(f'Fitting {algorithm} with {feature_set}')
        
        clf = TextClassifier(
            dataset=dataset, 
            algorithm=algorithm, 
            feature_set=feature_set, 
            max_n_features=10000, 
            embedding_model_name='glove-twitter-100'
        )

        CV = sklearn.model_selection.RandomizedSearchCV(
            clf.pipeline,
            param_distributions=clf.params,
            n_iter=10, 
            cv=3, 
            n_jobs=8,
            scoring='accuracy', 
            iid=False
        )
        
        X = dataset.get_texts('train')
        y = dataset.get_labels('train')
        CV = CV.fit(X, y)
        print(CV.best_score_)
        
        y_valid = dataset.get_labels('test')
        X_valid = dataset.get_texts('test')
        y_pred = CV.predict(X_valid)
        score = round(sklearn.metrics.accuracy_score(y_true=y_valid, y_pred=y_pred), 3)
        print(f'Best score for {algorithm} with {feature_set} on test set: {score}')
        
        best_t_params = CV.best_estimator_.get_params()
# Out:
# 2020-07-22 19:27:34,221 - root - DEBUG - Pre-computing feature_cache/new_hampshire_glove-twitter-100_mean.pkl
# 2020-07-22 19:27:34,222 - root - DEBUG - Transforming from cache
# 2020-07-22 19:27:34,223 - root - DEBUG - Cache not found
# 2020-07-22 19:27:34,224 - root - DEBUG - Transforming from scratch
# 2020-07-22 19:27:34,225 - root - DEBUG - Loading embedding model
# Fitting random_forest with embeddings
# [==================================================] 100.0% 387.1/387.1MB downloaded
# 2020-07-22 19:28:28,482 - smart_open.smart_open_lib - DEBUG - {'uri': '/Users/nikloynes/gensim-data/glove-twitter-100/glove-twitter-100.gz', 'mode': 'rb', 'buffering': -1, 'encoding': None, 'errors': None, 'newline': None, 'closefd': True, 'opener': None, 'ignore_ext': False, 'transport_params': None}
# 2020-07-22 19:30:26,364 - root - DEBUG - _load_embedding_model took 172.14s
# 2020-07-22 19:30:26,672 - root - DEBUG - fit_transform took 172.45s
# 2020-07-22 19:30:26,673 - root - DEBUG - Pre-computing feature_cache/new_hampshire_glove-twitter-100_max.pkl
# 2020-07-22 19:30:26,674 - root - DEBUG - Transforming from cache
# 2020-07-22 19:30:26,675 - root - DEBUG - Cache not found
# 2020-07-22 19:30:26,675 - root - DEBUG - Transforming from scratch
# 2020-07-22 19:30:26,676 - root - DEBUG - Loading embedding model
# 2020-07-22 19:30:26,758 - smart_open.smart_open_lib - DEBUG - {'uri': '/Users/nikloynes/gensim-data/glove-twitter-100/glove-twitter-100.gz', 'mode': 'rb', 'buffering': -1, 'encoding': None, 'errors': None, 'newline': None, 'closefd': True, 'opener': None, 'ignore_ext': False, 'transport_params': None}
# 2020-07-22 19:32:26,149 - root - DEBUG - _load_embedding_model took 119.47s
# 2020-07-22 19:32:26,526 - root - DEBUG - fit_transform took 119.85s
# 2020-07-22 19:32:40,261 - root - DEBUG - Transforming from cache
# 2020-07-22 19:32:40,276 - root - DEBUG - _load_from_cache took 0.01s
# 2020-07-22 19:32:40,279 - root - DEBUG - Checking if cache matches index docs
# 2020-07-22 19:32:40,287 - root - DEBUG - fit_transform took 0.03s
# 2020-07-22 19:32:42,290 - root - DEBUG - Transforming from cache
# 2020-07-22 19:32:42,296 - root - DEBUG - _load_from_cache took 0.01s
# 2020-07-22 19:32:42,298 - root - DEBUG - Checking if cache matches index docs
# 2020-07-22 19:32:42,302 - root - DEBUG - transform took 0.01s
# 2020-07-22 19:32:42,347 - root - DEBUG - Pre-computing feature_cache/new_hampshire_char_wb_(3, 3).joblib
# 2020-07-22 19:32:42,349 - root - DEBUG - Transforming from cache
# 2020-07-22 19:32:42,349 - root - DEBUG - Cache not found
# 2020-07-22 19:32:42,349 - root - DEBUG - Transforming from scratch
# 0.5799741862536467
# Best score for random_forest with embeddings on test set: 0.568
# Fitting random_forest with char_ngrams
# 2020-07-22 19:32:42,782 - root - DEBUG - fit_transform took 0.43s
# 2020-07-22 19:32:42,784 - root - DEBUG - Pre-computing feature_cache/new_hampshire_char_wb_(3, 4).joblib
# 2020-07-22 19:32:42,784 - root - DEBUG - Transforming from cache
# 2020-07-22 19:32:42,785 - root - DEBUG - Cache not found
# 2020-07-22 19:32:42,786 - root - DEBUG - Transforming from scratch
# 2020-07-22 19:32:43,369 - root - DEBUG - fit_transform took 0.58s
# 2020-07-22 19:32:43,370 - root - DEBUG - Pre-computing feature_cache/new_hampshire_char_wb_(3, 5).joblib
# 2020-07-22 19:32:43,370 - root - DEBUG - Transforming from cache
# 2020-07-22 19:32:43,371 - root - DEBUG - Cache not found
# 2020-07-22 19:32:43,372 - root - DEBUG - Transforming from scratch
# 2020-07-22 19:32:44,134 - root - DEBUG - fit_transform took 0.76s
# 2020-07-22 19:32:51,388 - root - DEBUG - Transforming from cache
# 2020-07-22 19:32:51,614 - root - DEBUG - _load_from_cache took 0.23s
# 2020-07-22 19:32:51,615 - root - DEBUG - Checking if cache matches index docs
# 2020-07-22 19:32:51,621 - root - DEBUG - fit_transform took 0.23s
# 2020-07-22 19:32:52,154 - root - DEBUG - Transforming from cache
# 0.9173164583966678
# 2020-07-22 19:32:52,381 - root - DEBUG - _load_from_cache took 0.23s
# 2020-07-22 19:32:52,382 - root - DEBUG - Checking if cache matches index docs
# 2020-07-22 19:32:52,387 - root - DEBUG - transform took 0.23s
# 2020-07-22 19:32:52,469 - root - DEBUG - Pre-computing feature_cache/new_hampshire_word_(1, 1).joblib
# 2020-07-22 19:32:52,470 - root - DEBUG - Transforming from cache
# 2020-07-22 19:32:52,471 - root - DEBUG - Cache not found
# 2020-07-22 19:32:52,472 - root - DEBUG - Transforming from scratch
# 2020-07-22 19:32:52,618 - root - DEBUG - fit_transform took 0.15s
# 2020-07-22 19:32:52,619 - root - DEBUG - Pre-computing feature_cache/new_hampshire_word_(1, 2).joblib
# 2020-07-22 19:32:52,620 - root - DEBUG - Transforming from cache
# 2020-07-22 19:32:52,620 - root - DEBUG - Cache not found
# 2020-07-22 19:32:52,621 - root - DEBUG - Transforming from scratch
# Best score for random_forest with char_ngrams on test set: 0.912
# Fitting random_forest with word_ngrams
# 2020-07-22 19:32:52,966 - root - DEBUG - fit_transform took 0.35s
# 2020-07-22 19:32:52,966 - root - DEBUG - Pre-computing feature_cache/new_hampshire_word_(1, 3).joblib
# 2020-07-22 19:32:52,967 - root - DEBUG - Transforming from cache
# 2020-07-22 19:32:52,968 - root - DEBUG - Cache not found
# 2020-07-22 19:32:52,968 - root - DEBUG - Transforming from scratch
# 2020-07-22 19:32:53,409 - root - DEBUG - fit_transform took 0.44s
# 2020-07-22 19:33:02,137 - root - DEBUG - Transforming from cache
# 2020-07-22 19:33:02,272 - root - DEBUG - _load_from_cache took 0.13s
# 2020-07-22 19:33:02,273 - root - DEBUG - Checking if cache matches index docs
# 2020-07-22 19:33:02,278 - root - DEBUG - fit_transform took 0.14s
# 2020-07-22 19:33:03,857 - root - DEBUG - Transforming from cache
# 2020-07-22 19:33:03,981 - root - DEBUG - _load_from_cache took 0.12s
# 2020-07-22 19:33:03,982 - root - DEBUG - Checking if cache matches index docs
# 2020-07-22 19:33:03,987 - root - DEBUG - transform took 0.13s
# 0.8306488530483155
# Best score for random_forest with word_ngrams on test set: 0.832
# Fitting elasticnet with embeddings
# 2020-07-22 19:33:04,404 - root - DEBUG - Transforming from cache
# 2020-07-22 19:33:04,409 - root - DEBUG - _load_from_cache took 0.00s
# 2020-07-22 19:33:04,411 - root - DEBUG - Checking if cache matches index docs
# 2020-07-22 19:33:04,418 - root - DEBUG - fit_transform took 0.01s
# /anaconda3/lib/python3.7/site-packages/sklearn/linear_model/stochastic_gradient.py:166: FutureWarning: max_iter and tol parameters have been added in SGDClassifier in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   FutureWarning)
# 2020-07-22 19:33:04,450 - root - DEBUG - Transforming from cache
# 2020-07-22 19:33:04,456 - root - DEBUG - _load_from_cache took 0.00s
# 2020-07-22 19:33:04,458 - root - DEBUG - Checking if cache matches index docs
# 2020-07-22 19:33:04,462 - root - DEBUG - transform took 0.01s
# 0.5306669866717867
# Best score for elasticnet with embeddings on test set: 0.532
# Fitting elasticnet with char_ngrams
# 2020-07-22 19:33:08,262 - root - DEBUG - Transforming from cache
# 2020-07-22 19:33:08,448 - root - DEBUG - _load_from_cache took 0.19s
# 2020-07-22 19:33:08,450 - root - DEBUG - Checking if cache matches index docs
# 2020-07-22 19:33:08,456 - root - DEBUG - fit_transform took 0.19s
# /anaconda3/lib/python3.7/site-packages/sklearn/linear_model/stochastic_gradient.py:166: FutureWarning: max_iter and tol parameters have been added in SGDClassifier in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   FutureWarning)
# 2020-07-22 19:33:08,491 - root - DEBUG - Transforming from cache
# 2020-07-22 19:33:08,660 - root - DEBUG - _load_from_cache took 0.17s
# 2020-07-22 19:33:08,661 - root - DEBUG - Checking if cache matches index docs
# 2020-07-22 19:33:08,666 - root - DEBUG - transform took 0.18s
# 0.902649663727953
# Best score for elasticnet with char_ngrams on test set: 0.868
# Fitting elasticnet with word_ngrams
# 2020-07-22 19:33:11,392 - root - DEBUG - Transforming from cache
# 2020-07-22 19:33:11,513 - root - DEBUG - _load_from_cache took 0.12s
# 2020-07-22 19:33:11,515 - root - DEBUG - Checking if cache matches index docs
# 2020-07-22 19:33:11,519 - root - DEBUG - fit_transform took 0.13s
# /anaconda3/lib/python3.7/site-packages/sklearn/linear_model/stochastic_gradient.py:166: FutureWarning: max_iter and tol parameters have been added in SGDClassifier in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   FutureWarning)
# 2020-07-22 19:33:11,528 - root - DEBUG - Transforming from cache
# 2020-07-22 19:33:11,663 - root - DEBUG - _load_from_cache took 0.13s
# 2020-07-22 19:33:11,664 - root - DEBUG - Checking if cache matches index docs
# 2020-07-22 19:33:11,669 - root - DEBUG - transform took 0.14s
# 0.8786494930585556
# Best score for elasticnet with word_ngrams on test set: 0.864
# Fitting svm with embeddings
# 2020-07-22 19:33:12,860 - root - DEBUG - Transforming from cache
# 2020-07-22 19:33:12,865 - root - DEBUG - _load_from_cache took 0.00s
# 2020-07-22 19:33:12,866 - root - DEBUG - Checking if cache matches index docs
# 2020-07-22 19:33:12,870 - root - DEBUG - fit_transform took 0.01s
# 2020-07-22 19:33:12,989 - root - DEBUG - Transforming from cache
# 2020-07-22 19:33:12,994 - root - DEBUG - _load_from_cache took 0.00s
# 2020-07-22 19:33:12,995 - root - DEBUG - Checking if cache matches index docs
# 2020-07-22 19:33:12,999 - root - DEBUG - transform took 0.01s
# 0.574619348576244
# Best score for svm with embeddings on test set: 0.584
# Fitting svm with char_ngrams
# 2020-07-22 19:33:20,704 - root - DEBUG - Transforming from cache
# 2020-07-22 19:33:20,822 - root - DEBUG - _load_from_cache took 0.12s
# 2020-07-22 19:33:20,823 - root - DEBUG - Checking if cache matches index docs
# 2020-07-22 19:33:20,829 - root - DEBUG - fit_transform took 0.12s
# 2020-07-22 19:33:21,119 - root - DEBUG - Transforming from cache
# 2020-07-22 19:33:21,233 - root - DEBUG - _load_from_cache took 0.11s
# 2020-07-22 19:33:21,234 - root - DEBUG - Checking if cache matches index docs
# 2020-07-22 19:33:21,238 - root - DEBUG - transform took 0.12s
# 0.899988351813629
# Best score for svm with char_ngrams on test set: 0.872
# Fitting svm with word_ngrams
# 2020-07-22 19:33:24,384 - root - DEBUG - Transforming from cache
# 2020-07-22 19:33:24,507 - root - DEBUG - _load_from_cache took 0.12s
# 2020-07-22 19:33:24,508 - root - DEBUG - Checking if cache matches index docs
# 2020-07-22 19:33:24,512 - root - DEBUG - fit_transform took 0.13s
# 2020-07-22 19:33:24,610 - root - DEBUG - Transforming from cache
# 2020-07-22 19:33:24,734 - root - DEBUG - _load_from_cache took 0.12s
# 2020-07-22 19:33:24,735 - root - DEBUG - Checking if cache matches index docs
# 2020-07-22 19:33:24,739 - root - DEBUG - transform took 0.13s
# 0.8733106769708315
# Best score for svm with word_ngrams on test set: 0.872
# Fitting naive_bayes with embeddings
# 2020-07-22 19:33:25,067 - root - DEBUG - Transforming from cache
# 2020-07-22 19:33:25,071 - root - DEBUG - _load_from_cache took 0.00s
# 2020-07-22 19:33:25,072 - root - DEBUG - Checking if cache matches index docs
# 2020-07-22 19:33:25,076 - root - DEBUG - fit_transform took 0.01s
# 2020-07-22 19:33:25,080 - root - DEBUG - Transforming from cache
# 2020-07-22 19:33:25,085 - root - DEBUG - _load_from_cache took 0.00s
# 2020-07-22 19:33:25,086 - root - DEBUG - Checking if cache matches index docs
# 2020-07-22 19:33:25,090 - root - DEBUG - transform took 0.01s
# 0.42136989925172136
# Best score for naive_bayes with embeddings on test set: 0.42
# Fitting naive_bayes with char_ngrams
# ---------------------------------------------------------------------------
# _RemoteTraceback                          Traceback (most recent call last)
# _RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/externals/loky/process_executor.py", line 418, in _process_worker
#     r = call_item()
#   File "/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/externals/loky/process_executor.py", line 272, in __call__
#     return self.fn(*self.args, **self.kwargs)
#   File "/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/_parallel_backends.py", line 567, in __call__
#     return self.func(*args, **kwargs)
#   File "/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py", line 225, in __call__
#     for func, args, kwargs in self.items]
#   File "/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py", line 225, in <listcomp>
#     for func, args, kwargs in self.items]
#   File "/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_validation.py", line 528, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/anaconda3/lib/python3.7/site-packages/sklearn/pipeline.py", line 267, in fit
#     self._final_estimator.fit(Xt, y, **fit_params)
#   File "/anaconda3/lib/python3.7/site-packages/sklearn/naive_bayes.py", line 190, in fit
#     X, y = check_X_y(X, y)
#   File "/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py", line 756, in check_X_y
#     estimator=estimator)
#   File "/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py", line 517, in check_array
#     accept_large_sparse=accept_large_sparse)
#   File "/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py", line 318, in _ensure_sparse_format
#     raise TypeError('A sparse matrix was passed, but dense '
# TypeError: A sparse matrix was passed, but dense data is required. Use X.toarray() to convert to a dense numpy array.
# """
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-55-91d39db234fe> in <module>
#      22         X = dataset.get_texts('train')
#      23         y = dataset.get_labels('train')
# ---> 24         CV = CV.fit(X, y)
#      25         print(CV.best_score_)
#      26
#
# /anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     720                 return results_container[0]
#     721
# --> 722             self._run_search(evaluate_candidates)
#     723
#     724         results = results_container[0]
#
# /anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_search.py in _run_search(self, evaluate_candidates)
#    1513         evaluate_candidates(ParameterSampler(
#    1514             self.param_distributions, self.n_iter,
# -> 1515             random_state=self.random_state))
#
# /anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_search.py in evaluate_candidates(candidate_params)
#     709                                for parameters, (train, test)
#     710                                in product(candidate_params,
# --> 711                                           cv.split(X, y, groups)))
#     712
#     713                 all_candidate_params.extend(candidate_params)
#
# /anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py in __call__(self, iterable)
#     928
#     929             with self._backend.retrieval_context():
# --> 930                 self.retrieve()
#     931             # Make sure that we get a last message telling us we are done
#     932             elapsed_time = time.time() - self._start_time
#
# /anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py in retrieve(self)
#     831             try:
#     832                 if getattr(self._backend, 'supports_timeout', False):
# --> 833                     self._output.extend(job.get(timeout=self.timeout))
#     834                 else:
#     835                     self._output.extend(job.get())
#
# /anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/_parallel_backends.py in wrap_future_result(future, timeout)
#     519         AsyncResults.get from multiprocessing."""
#     520         try:
# --> 521             return future.result(timeout=timeout)
#     522         except LokyTimeoutError:
#     523             raise TimeoutError()
#
# /anaconda3/lib/python3.7/concurrent/futures/_base.py in result(self, timeout)
#     430                 raise CancelledError()
#     431             elif self._state == FINISHED:
# --> 432                 return self.__get_result()
#     433             else:
#     434                 raise TimeoutError()
#
# /anaconda3/lib/python3.7/concurrent/futures/_base.py in __get_result(self)
#     382     def __get_result(self):
#     383         if self._exception:
# --> 384             raise self._exception
#     385         else:
#     386             return self._result
#
# TypeError: A sparse matrix was passed, but dense data is required. Use X.toarray() to convert to a dense numpy array.
